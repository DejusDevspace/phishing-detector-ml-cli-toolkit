# %%
import pandas as pd
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv("datasets/feature_selected_data.csv", index_col=0)

# %%
df.head()
# Out:
#    domain_token_count  avgdomaintokenlen  longdomaintokenlen  avgpathtokenlen  \
# 0                   4                5.5                  14         4.400000
# 1                   4                5.5                  14         6.000000
# 2                   4                5.5                  14         5.800000
# 3                   4                5.5                  14         5.500000
# 4                   4                5.5                  14         7.333334
#
#    tld  ldl_url  ldl_path  urlLen  domainlength  pathLength  subDirLen  \
# 0    4        0         0      58            25          26         26
# 1    4        0         0      66            25          34         34
# 2    4        0         0      65            25          33         33
# 3    4        0         0     109            25          77         77
# 4    4        0         0      81            25          49         49
#
# ...

# %%
df.shape
# Out:
# (26953, 46)

# %%
cols_with_neg = []
for col in df.columns:
    if df[col].isin([-1]).any():
        cols_with_neg.append(col)
print("Columns with -1 values:", cols_with_neg)
# Out:
# Columns with -1 values: ['Extension_DigitCount', 'Query_DigitCount', 'Directory_LetterCount', 'Filename_LetterCount', 'Extension_LetterCount', 'Query_LetterCount', 'Arguments_LongestWordLength', 'delimeter_Count', 'NumberRate_FileName', 'NumberRate_Extension', 'NumberRate_AfterPath', 'SymbolCount_Directoryname', 'SymbolCount_FileName', 'SymbolCount_Extension', 'Entropy_Filename']

# %%
len(cols_with_neg)
# Out:
# 15
